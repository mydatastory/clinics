# %% [markdown]
# # The Individual and Racial Inevitability-
# ## The Data Story inside Richard Wright's Native Son

# %% [markdown]
# ![crime_movie_fig.jpeg](attachment:crime_movie_fig.jpeg)

# %% [markdown]
# ![mydatastory_footer.png](attachment:mydatastory_footer.png)

# %% [markdown]
# ### Violent Crime by Neighborhood in Chicago
#
# Using geogrpahical crime data from the Chicago police department and a map of Chicago neighborhood boundaries, identify the relationship between neighborhood and crime with maps.

# %%
#### Prep code

# %%
#### Subset by date range

# %%
#### Print unique values in a column

# %%
#### Subset by string values in column

# %%
#### Import map with Folium

# %%
#### Import shape file with JSON

# %%
#### Create HeatMap with Folium

# %%
#### Create markers and add to map with Folium

# %% [markdown]
# ### Segregation in the South Side of Chicago
# Using the racial makeup of chicago's neighborhoods to analyze the relationshop between school based gun crime and black neighborhoods.

# %% [markdown]
# ![crime_southside_fig.jpg](attachment:crime_southside_fig.jpg)

# %%
#### Print unique values in a column

# %%
#### Subset by string value

# %%
#### Import shape file with JSON

# %%
#### Create Choropleth with Folium

# %%
#### Create HeatMap and add to map with Folium

# %%
#### Create markers and add to map with Folium

# %%
#### Save map as HTML

# %% [markdown]
# ### Race and the Illinois Penitentiary System
# One of the issues raised in Native SOn is the inevitablility of young black men towards criminal activity, largely a a result of JIm Cro laws in the AMericna SOuth. A generation later, Michelle Alexander argues that the current mass incacecration experienced int he United STates as a result of the "war on drugs" and the "tough on crime" movements as resulted in a new version of Jim Crow. Read a the synopsis of the book to understand her core arguments.
#
# [The New Jim Crow](_doc/crime_newjim_doc.pdf)
#
# Using data from the Illinois census of the individual currently incarcerated in the state to determine the relationshop between race and incarceration in Chicago.

# %% [markdown]
# ![crime_jimcrow_fig.jpg](attachment:crime_jimcrow_fig.jpg)

# %%
#### Subset by column string value

# %%
#### Print unique values in a column

# %%
#### Subset by column string value

# %%
#### Create pie chart with Matplotlib

# %% [markdown]
# ## Using data to understand race, crime, and segregation
#
# #### Violent Crime by Neighborhood
#
# #### School based Crime in Black Neighborhoods
#
# #### High rates of increceration for African-Ameircans from Chicago
#
# #### Discussion

# %% [markdown]
# ## East and West Gainesville
# Historicall West Gainesville has housed predominantly neighborhoods, while East Gainesville has contained most of the historically black neighborhoods. While this has changed over time, Main St still functions as a defacto segregation line. Using Gainesville crime data, map the occurence of crime in the city and evaluate the historical racial makeup of the neighborhoods.

# %% [markdown]
# ![crime_gnv_fig.jpg](attachment:crime_gnv_fig.jpg)

# %% [markdown]
# #### [Answer](#answer_key)
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ******
# ### <a id='answer_key'> Answer </a>

# %%
#### Prep code

# %%
#### Subset by column value

# %%
#### Import map with Folium

# %%
#### Create HeatMap with Folium

# %% [markdown]
# ![mydatastory_footer.png](attachment:mydatastory_footer.png)
